# %%
from collections import Counter
import os

from graphviz import Source
from IPython.display import display, Markdown
import matplotlib.pyplot as plt
from matplotlib.ticker import EngFormatter
import networkx as nx
import numpy as np
from scipy import stats
import pandas as pd
import seaborn as sns


sns.set_style('white')
sns.set_context('notebook')
pd.set_option('max_rows', 1000)
pd.set_option('max_columns', 100)

def plot_style(figsize=(12, 6), labelsize=20, titlesize=24, ticklabelsize=14, **kwargs):
   basic_style = {
       'figure.figsize': figsize,
       'axes.labelsize': labelsize,
       'axes.titlesize': titlesize,
       'xtick.labelsize': ticklabelsize,
       'ytick.labelsize': ticklabelsize,
       'axes.spines.top': False,
       'axes.spines.right': False,
       'axes.spines.left': False,
       'axes.grid': False,
       'axes.grid.axis': 'y',
   }
   basic_style.update(kwargs)
   return plt.rc_context(rc=basic_style)

blue = sns.xkcd_rgb['ocean blue']

# %%
from graphviz import Source
import networkx as nx

# %%
def new_count_row(all_clone_names, clone_name=None):
    """ Create a DataFrame row with one entry per clone name. 
    
    If `clone_name` is not None, initialize that entry to 1.
    """
    row = pd.Series(data=0, index=all_clone_names)
    if clone_name is not None:
        row[clone_name] = 1
    return row

def dfs_clones_count(g, clones, all_clone_names, source_node):
    clones_count = pd.DataFrame({sample_name: new_count_row(all_clones, clone_name) for sample_name, clone_name in clones.items()})
    for pre_node, post_node, edge_label in nx.dfs_labeled_edges(g, source_node):
        if edge_label is not 'reverse' or pre_node == post_node: 
            continue
        pre_node_counter = clones_count.get(pre_node, new_count_row(all_clones))
        if post_node not in clones_count.columns:
            print('!! possible mutation in a leaf: not found', post_node)
            continue
        clones_count[pre_node] = pre_node_counter + clones_count[post_node]

    return clones_count

def purity(clones_count):
    return clones_count.div(clones_count.sum(axis=0), axis=1)

def get_root_node(t):
    root_nodes = [n for n,d in t.in_degree() if d==0]
    assert len(root_nodes) == 1
    root_node = root_nodes[0]
    return root_node
# Out:
# <>:14: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:14: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-51-25b16f03b063>:14: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if edge_label is not 'reverse' or pre_node == post_node:

# %% [markdown]
# # Load clone map

# %%
#clones_map_raw = pd.read_csv('data/invivo_scRNAseq/train_results/sample_order_clone_key.txt')
#clones_map_raw = pd.read_csv('data/atac/final_tests/matrix_output/sample_order_full.txt')
clones_map_raw = pd.read_csv('data/invivo_scRNAseq/test_results/sample_order_clone_key.txt')


clones_map_raw['node_name'] = 's' + clones_map_raw['tree_id'].astype(str)
clones_map_raw
# Out:
#      clone tree_id        cell_id node_name
# 0     bulk      s0  P3861_210.txt       ss0
# 1    153.0     s24     P1299_1099      ss24
# 2    153.0     s25     P1299_1101      ss25
# 3    153.0     s97     P1299_1322      ss97
# 4    153.0     s98     P1299_1362      ss98
# 5    153.0     s42     P1902_1147      ss42
# 6    153.0     s79     P1902_1277      ss79
# 7    153.0     s95     P3128_1166      ss95
# 8    192.0     s26     P1299_1189      ss26
# 9    192.0    s106     P1299_1465     ss106
# 10   192.0    s107     P1299_1478     ss107
# 11   192.0     s78     P1902_1276      ss78
# 12   200.0     s30     P1299_1887      ss30
# 13   200.0     s33     P1299_1918      ss33
# 14   200.0    s100     P1299_2101     ss100
# 15   242.0    s113     P1299_1525     ss113
# 16   242.0     s44     P1902_1151      ss44
# 17   242.0     s73     P1902_1211      ss73
# 18   242.0     s55     P3128_1059      ss55
# 19   281.0    s136     P1299_1754     ss136
# 20   281.0     s58     P3128_1083      ss58
# 21   281.0     s60     P3128_1087      ss60
# 22   281.0     s82     P3128_1099      ss82
# 23   281.0     s84     P3128_1103      ss84
# 24   307.0     s62     P1299_1235      ss62
# 25   307.0    s118     P1299_1574     ss118
# 26   307.0    s129     P1299_1670     ss129
# 27   307.0     s89     P3128_1145      ss89
# 28   353.0    s112     P1299_1523     ss112
# 29   353.0    s124     P1299_1655     ss124
# 30   353.0     s75     P1902_1227      ss75
# 31   504.0    s109     P1299_1503     ss109
# 32   504.0    s135     P1299_1735     ss135
# 33   504.0    s137     P1299_1758     ss137
# 34    68.0      s1     P1299_1789       ss1
# 35    68.0      s6     P1299_1845       ss6
# 36    68.0      s7     P1299_1846       ss7
# 37    68.0      s8     P1299_1852       ss8
# 38    68.0     s29     P1299_1883      ss29
# 39    68.0     s31     P1299_1890      ss31
# 40    68.0     s32     P1299_1902      ss32
# 41    68.0     s34     P1299_1925      ss34
# 42    68.0     s36     P1299_1941      ss36
# 43    68.0     s64     P1299_2007      ss64
# 44    79.0      s2     P1299_1822       ss2
# 45    79.0      s5     P1299_1835       ss5
# 46    79.0     s27     P1299_1875      ss27
# 47    79.0     s28     P1299_1876      ss28
# 48    79.0     s38     P1299_1954      ss38
# 49    79.0     s67     P1299_2030      ss67
# 50    79.0     s68     P1299_2041      ss68
# 51    79.0    s101     P1299_2113     ss101
# 52    79.0    s102     P1299_2117     ss102
# 53    79.0    s103     P1299_2120     ss103
# 54    79.0    s104     P1299_2144     ss104
# 55    79.0    s105     P1299_2154     ss105
# 56    82.0      s3     P1299_1829       ss3
# 57    82.0     s37     P1299_1951      ss37
# 58    82.0     s65     P1299_2020      ss65
# 59    82.0     s66     P1299_2021      ss66
# 60    82.0     s99     P1299_2079      ss99
# 61    83.0      s4     P1299_1831       ss4
# 62    83.0     s63     P1299_2001      ss63
# 63    83.0     s69     P1299_2046      ss69
# 64    89.0      s9     P1299_1860       ss9
# 65    89.0     s35     P1299_1937      ss35
# 66    89.0     s70     P1299_2059      ss70
# 67    92.0    s110     P1299_1515     ss110
# 68    92.0    s111     P1299_1520     ss111
# 69    92.0    s114     P1299_1527     ss114
# 70    92.0    s117     P1299_1571     ss117
# 71    92.0    s127     P1299_1661     ss127
# 72    92.0    s128     P1299_1669     ss128
# 73    92.0    s130     P1299_1706     ss130
# 74    92.0    s132     P1299_1718     ss132
# 75    92.0    s133     P1299_1729     ss133
# 76    92.0    s138     P1299_1762     ss138
# 77    92.0     s10     P1902_1001      ss10
# 78    92.0     s43     P1902_1150      ss43
# 79    92.0     s72     P1902_1202      ss72
# 80    92.0     s52     P3128_1048      ss52
# 81    92.0     s53     P3128_1055      ss53
# 82    92.0     s86     P3128_1135      ss86
# 83    92.0     s93     P3128_1160      ss93
# 84    95.0    s108     P1299_1483     ss108
# 85    95.0    s115     P1299_1532     ss115
# 86    95.0    s116     P1299_1543     ss116
# 87    95.0    s119     P1299_1580     ss119
# 88    95.0    s120     P1299_1623     ss120
# 89    95.0    s121     P1299_1627     ss121
# 90    95.0    s122     P1299_1637     ss122
# 91    95.0    s123     P1299_1652     ss123
# 92    95.0    s126     P1299_1659     ss126
# 93    95.0    s131     P1299_1713     ss131
# 94    95.0    s134     P1299_1732     ss134
# 95    95.0     s11     P1902_1005      ss11
# 96    95.0     s12     P1902_1007      ss12
# 97    95.0     s13     P1902_1011      ss13
# 98    95.0     s15     P1902_1013      ss15
# 99    95.0     s16     P1902_1021      ss16
# 100   95.0     s17     P1902_1024      ss17
# 101   95.0     s18     P1902_1025      ss18
# 102   95.0     s20     P1902_1032      ss20
# 103   95.0     s21     P1902_1039      ss21
# 104   95.0     s22     P1902_1078      ss22
# 105   95.0     s23     P1902_1080      ss23
# 106   95.0     s39     P1902_1113      ss39
# 107   95.0     s40     P1902_1118      ss40
# 108   95.0     s41     P1902_1145      ss41
# 109   95.0     s45     P1902_1162      ss45
# 110   95.0     s46     P1902_1169      ss46
# 111   95.0     s47     P1902_1172      ss47
# 112   95.0     s48     P1902_1182      ss48
# 113   95.0     s71     P1902_1197      ss71
# 114   95.0     s74     P1902_1212      ss74
# 115   95.0     s76     P1902_1241      ss76
# 116   95.0     s77     P1902_1244      ss77
# 117   95.0     s80     P1902_1286      ss80
# 118   95.0     s49     P3128_1003      ss49
# 119   95.0     s50     P3128_1018      ss50
# 120   95.0     s51     P3128_1036      ss51
# 121   95.0     s54     P3128_1058      ss54
# 122   95.0     s56     P3128_1066      ss56
# 123   95.0     s57     P3128_1079      ss57
# 124   95.0     s61     P3128_1090      ss61
# 125   95.0     s81     P3128_1097      ss81
# 126   95.0     s83     P3128_1102      ss83
# 127   95.0     s85     P3128_1134      ss85
# 128   95.0     s87     P3128_1136      ss87
# 129   95.0     s88     P3128_1137      ss88
# 130   95.0     s90     P3128_1151      ss90
# 131   95.0     s91     P3128_1156      ss91
# 132   95.0     s92     P3128_1157      ss92
# 133   95.0     s94     P3128_1162      ss94
# 134   95.0     s96     P3128_1183      ss96
# 135   97.0    s125     P1299_1658     ss125
# 136   97.0     s14     P1902_1012      ss14
# 137   97.0     s19     P1902_1031      ss19
# 138   97.0     s59     P3128_1084      ss59

# %%
clones_map = dict(clones_map_raw[['tree_id', 'clone']].values)
all_clones = list(clones_map_raw.clone.unique())

# %%
all_clones
# Out:
# ['bulk',
#  '153.0',
#  '192.0',
#  '200.0',
#  '242.0',
#  '281.0',
#  '307.0',
#  '353.0',
#  '504.0',
#  '68.0',
#  '79.0',
#  '82.0',
#  '83.0',
#  '89.0',
#  '92.0',
#  '95.0',
#  '97.0']

# %%
#flatui = ["#7BCAB1", "#FC8D62", "#8DA0CB", "#4B4B71", "#FECD4C", "#91304C"]

flatui = ["#BA47AF", "#F74B91", "#A7A7E8", "#BABABA", "#C7003A", "#FF5733", "#FF8D19", "#FFC300", "#EEDD54", "#ADD55C", "#57C785", "#00BBAD", "#2A7B9B", "#3D3D6B", "#511849", "#900C3F", ]


#flatui = ["#4A4A71", "#FECD4C", "#92304C"]
sns.palplot(sns.color_palette(flatui))

# %%
#flatui = ["7BCAB1", "#2EBAAE", "#AED265", "#FECD4C", "#F06247", "#92304C"]
#sns.color_palette(sns.color_palette(flatui))

# %%
#sns.palplot(sns.color_palette("Set2", len(all_clones) - 1))
sns.palplot(sns.color_palette("tab20", len(all_clones) - 1))

# %%
#sns.color_palette("Set2", len(all_clones) - 1)

# %%
#colors = sns.color_palette("Set2", len(all_clones) - 1)
flatui = ["#BA47AF", "#F74B91", "#A7A7E8", "#BABABA", "#C7003A", "#FF5733", "#FF8D19", "#FFC300", "#EEDD54", "#ADD55C", "#57C785", "#00BBAD", "#2A7B9B", "#3D3D6B", "#511849", "#900C3F", ]
colors = sns.color_palette(sns.color_palette(flatui))

#clone_color = {
#    'bulk': (0, 0, 0),
#    '107.0': np.array(colors[0]) * 255,
#    '108.0': np.array(colors[1]) * 255,
#    '118.0': np.array(colors[2]) * 255,
#    '122.0': np.array(colors[3]) * 255,
#    '143.0': np.array(colors[4]) * 255,
#    '149.0': np.array(colors[5]) * 255,
#}


#clone_color = {
#    'bulk': (0, 0, 0),
#    'A': np.array(colors[0]) * 255,
#    'B': np.array(colors[1]) * 255,
#    'C': np.array(colors[2]) * 255,
#    'D': np.array(colors[3]) * 255,
#    'E': np.array(colors[4]) * 255,
#    'F': np.array(colors[5]) * 255,
#}



clone_color = {
    'bulk': (0, 0, 0),
    '153.0': np.array(colors[0]) * 255,
    '192.0': np.array(colors[1]) * 255,
    '200.0': np.array(colors[2]) * 255,
    '242.0': np.array(colors[3]) * 255,
    '281.0': np.array(colors[4]) * 255,
    '307.0': np.array(colors[5]) * 255,
    '353.0': np.array(colors[6]) * 255,
    '504.0': np.array(colors[7]) * 255,
    '68.0': np.array(colors[8]) * 255,
    '79.0': np.array(colors[9]) * 255,
    '82.0': np.array(colors[10]) * 255,
    '83.0': np.array(colors[11]) * 255,
    '89.0': np.array(colors[12]) * 255,
    '92.0': np.array(colors[13]) * 255,
    '95.0': np.array(colors[14]) * 255,
    '97.0': np.array(colors[15]) * 255,
}

# %%
clone_color
# Out:
# {'bulk': (0, 0, 0),
#  '153.0': array([186.,  71., 175.]),
#  '192.0': array([247.,  75., 145.]),
#  '200.0': array([167., 167., 232.]),
#  '242.0': array([186., 186., 186.]),
#  '281.0': array([199.,   0.,  58.]),
#  '307.0': array([255.,  87.,  51.]),
#  '353.0': array([255., 141.,  25.]),
#  '504.0': array([255., 195.,   0.]),
#  '68.0': array([238., 221.,  84.]),
#  '79.0': array([173., 213.,  92.]),
#  '82.0': array([ 87., 199., 133.]),
#  '83.0': array([  0., 187., 173.]),
#  '89.0': array([ 42., 123., 155.]),
#  '92.0': array([ 61.,  61., 107.]),
#  '95.0': array([81., 24., 73.]),
#  '97.0': array([144.,  12.,  63.])}

# %% [markdown]
# # Load target tree

# %%
error_rate = 0.0778

#error_rate = 0.0005
tree_number = 0

#tree_filename = f'data/invivo_scRNAseq/train_results_nc/tree_output/dot_files_scRNAseq_nc/{error_rate}_map{tree_number}.gv'
#tree_filename = f'data/atac/train_atac_results/dot_files/{error_rate}_map{tree_number}.gv'
#tree_filename = f'data/atac/final_tests/from_meeting_ludwig/0.0005_atac_for_ludwig_prez_map0.gv'
#tree_filename = f'data/tree_output/too_many_nucleotides_and_low_dp_flt_0.0778_map0.gv'
tree_filename = f'data/tree_output/0.0778_map0.gv'


tree = nx.drawing.nx_pydot.read_dot(tree_filename)

# %% [markdown]
# # Decorate the nodes

# %%
mix_clones_colors(n, clones_purity)
# Out:
# array([0, 0, 0])

# %%
def rgb_to_hex(colortuple):
    return '#' + ''.join(f'{int(i):02X}' for i in colortuple)

def mix_clones_colors(node_name, purities):
    node_purities = purities[node_name]
    color = 0
    for clone, frac in node_purities.iteritems():
        color += frac * np.array(clone_color[clone])
    return color.astype(int)


clones_count = dfs_clones_count(tree, clones_map, all_clones, source_node=get_root_node(tree))
clones_purity = purity(clones_count)

for n in tree.nodes:
    node_dict = tree.nodes[n]
    if n.startswith('s'):
        # This is the style for sample nodes
        clone = clones_map[n]
        node_dict['color'] = rgb_to_hex(clone_color[clone])
        node_dict['shape'] = 'circle' #square
    else:
        if n in clones_purity:
            # This is the style for mutation nodes
            # Color is a mix of purities
            node_dict['color'] = rgb_to_hex(mix_clones_colors(n, clones_purity))
        else:
            # Dangling mutation node
            node_dict['color'] = 'black'
# Out:
# !! possible mutation in a leaf: not found 53
# !! possible mutation in a leaf: not found 33
# !! possible mutation in a leaf: not found 5

# %%
# Global graph style
tree.graph['node']['shape'] = 'square' #circle
tree.graph['node']['fontcolor'] = 'white'
tree.graph['edges'] = {'arrowsize': '4'}
tree.graph
# Out:
# {'name': 'G',
#  'node': {'color': 'deeppink4',
#   'style': 'filled',
#   'fontcolor': 'white',
#   'shape': 'square'},
#  'edges': {'arrowsize': '4'}}

# %%
from networkx.drawing.nx_agraph import graphviz_layout, to_agraph
g = to_agraph(tree)

# %%
from networkx.drawing.nx_agraph import graphviz_layout, to_agraph
g = to_agraph(tree)
g.layout('dot')
g.draw(f'figs/trees/{error_rate}_map{tree_number}.pdf')
#g.draw(f'figs/trees/{error_rate}_map{tree_number}too_many_n_low_dp.pdf')
Source(g)

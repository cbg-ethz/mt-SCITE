# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from Bio import SeqIO
from glob import glob
import os

# Plotting style
sns.set_style('white')
sns.set_context('notebook')
pd.set_option('max_rows', 1000)
pd.set_option('max_columns', 100)

def plot_style(figsize=(12, 6), labelsize=20, titlesize=24, ticklabelsize=14, **kwargs):
   basic_style = {
       'figure.figsize': figsize,
       'axes.labelsize': labelsize,
       'axes.titlesize': titlesize,
       'xtick.labelsize': ticklabelsize,
       'ytick.labelsize': ticklabelsize,
       'axes.spines.top': False,
       'axes.spines.right': False,
       'axes.spines.left': False,
       'axes.grid': False,
       'axes.grid.axis': 'y',
   }
   basic_style.update(kwargs)
   return plt.rc_context(rc=basic_style)

blue = sns.xkcd_rgb['ocean blue']

# %% [markdown]
# ## Coverage plots

# %%
# Coverage dataset 1

plt.figure(figsize=(16, 6))
A1 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/train_atac_data/P9855_2089_S112_L004_ac.txt', sep='\t')
A2 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/train_atac_data/P9855_2090_S113_L004_ac.txt', sep='\t')

B1 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/train_atac_data/P9855_2104_S127_L006_ac.txt', sep='\t')
B2 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/train_atac_data/P9855_2112_S135_L007_ac.txt', sep='\t')

C1 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/train_atac_data/P9855_2110_S133_L007_ac.txt', sep='\t')
C2 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/train_atac_data/P9855_2111_S134_L007_ac.txt', sep='\t')

ax = sns.lineplot(data=A1["Good_depth"], color = '#E25754')


ax = sns.lineplot(data=B1["Good_depth"], color = '#15A460')
ax = sns.lineplot(data=B2["Good_depth"], color = '#15A460')


ax = sns.lineplot(data=C1["Good_depth"], color = '#276AA5')
ax = sns.lineplot(data=C2["Good_depth"], color = '#276AA5')

ax = sns.lineplot(data=B2["Good_depth"], color = '#E25754')


plt.grid(axis='both')
#plt.savefig('../../../manuscript/Probability_SCITE/illustrations/other_plots/atac_train.png', dpi=300)

# %%
# Coverage dataset 2

plt.figure(figsize=(16, 6))

D1 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/test_atac_data/P9855_2091_S114_L004_ac.txt', sep='\t')
D2 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/test_atac_data/P9855_2096_S119_L005_ac.txt', sep='\t')

E1 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/test_atac_data/P9855_2085_S108_L004_ac.txt', sep='\t')
E2 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/test_atac_data/P9855_2093_S116_L005_ac.txt', sep='\t')

F1 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/test_atac_data/P9855_2101_S124_L006_ac.txt', sep='\t')
F2 = pd.read_csv('../kth_data_science_assignment_4_aug2020/data/atac/test_atac_data/P9855_2102_S125_L006_ac.txt', sep='\t')



ax = sns.lineplot(data=D1["Good_depth"], color='#A9D9D7')
ax = sns.lineplot(data=D2["Good_depth"], color = '#A9D9D7')

ax = sns.lineplot(data=E1["Good_depth"], color = '#7B6DA4')
ax = sns.lineplot(data=E2["Good_depth"], color = '#7B6DA4')

ax = sns.lineplot(data=F1["Good_depth"], color = '#EFB771')
ax = sns.lineplot(data=F2["Good_depth"], color = '#EFB771')

plt.grid(axis='both')
plt.savefig('../../../manuscript/Probability_SCITE/illustrations/other_plots/atac_test.png', dpi=300)

# %% [markdown]
# ## Generate clone key for scRNAseq data

# %%
# Generate clone key for scRNAseq data

s_order = pd.read_csv('data/matrix_output/sample_order_test_clean.txt', sep='\t')
clone_key = pd.read_csv('data/invivo_scRNAseq/invivo_scRNAseq_labels_sorted.txt', sep='\t')
merged = pd.merge(clone_key, s_order, on='cell_id')
merged = merged[['clone', 'tree_id', 'cell_id']]
merged
merged.to_csv('data/matrix_output/sample_order_clone_key.txt', index=False, sep=',')

# %% [markdown]
# ## Stats files
